# %%
import numpy as np
from data_management import *
from var import *

R0 = var(50, 2.5)
v_phi = var(2e8, 1e7)

M = """100	9.88	0.01
200	19.76	0.01
300	29.9	0.1"""

M = text2mat(M)
l = var(M[:,0], 0.01)
C = var(M[:,1], M[:,2])
